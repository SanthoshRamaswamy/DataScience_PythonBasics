# %% [markdown]
# <a href="https://colab.research.google.com/github/SanthoshRamaswamy/DataScience_PythonBasics/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("http://rcs.bu.edu/examples/python/data_analysis/Salaries.csv")

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.head(20)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
df.head(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 468

# %%
df.shape
# Out:
# (78, 6)

# %%
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
df.align
# Out:
# <bound method DataFrame.align of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df.all
# Out:
# <bound method DataFrame.all of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df.any
# Out:
# <bound method DataFrame.any of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
#to find no of records
df.size
# Out:
# 468

# %%
#to find no of columns
df.shape
# Out:
# (78, 6)

# %%
#to find column names
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
#to find column type
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
#summary for all numerical columns
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
#std deviation for numerical columns
df.std()
# Out:
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
#mean of first 50 records
df.head(50).mean()
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.mean().head(50)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.salary
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df[['salary']]
# Out:
#     salary
# 0   186960
# 1    93000
# 2   110515
# 3   131205
# 4   104800
# ..     ...
# 73  105450
# 74  104542
# 75  124312
# 76  109954
# 77  109646
#
# [78 rows x 1 columns]

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.phd
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64

# %%
df.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.phd.count()
# Out:
# 78

# %%
df.phd.mean()
# Out:
# 19.705128205128204

# %%
df.groupby(['rank'])

# %%
#grouping by rank
df.groupby('rank').mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby('rank')['salary'].mean()
# Out:
# rank
# AssocProf     91786.230769
# AsstProf      81362.789474
# Prof         123624.804348
# Name: salary, dtype: float64

# %%
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df.groupby('rank')[['salary', 'phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
#to get rows where salary is greater than 120000
df[df.salary>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
#to get rows where service is greater than 10
df[df.service>10]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 19       Prof          A   29       27    Male  150500
# 21       Prof          A   33       30    Male  103106
# 24       Prof          A   30       23    Male   91100
# ...

# %%
#tp get only rows which has sex=Female
df[df.sex=='Female']
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# ...

# %%
df[[df.service>10 , df.sex==Female]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-ee5c8519dbb4> in <module>()
# ----> 1 df[[df.service>10 , df.sex==Female]]
#
# NameError: name 'Female' is not defined

# %%
[(df[df.service>10]) & (df.sex=='Female')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     265         #  (xint or xbool) and (yint or bool)
# --> 266         result = op(x, y)
#     267     except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'str' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-b9465983bd4f> in <module>()
# ----> 1 [(df[df.service>10]) & (df.sex=='Female')]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#     653         if isinstance(other, ABCDataFrame):
#     654             # Another DataFrame
# --> 655             new_data = self._combine_frame(other, na_op, fill_value)
#     656
# ...

# %%
 df[(df.sex=='Female') & (df.service>10)]
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 51       Prof          B   20       14  Female  127512
# 54  AssocProf          A   25       22  Female   62884
# 58       Prof          B   36       26  Female  144651
# 63       Prof          A   29       27  Female   91000
# 64  AssocProf          A   26       24  Female   73300
# 65       Prof          A   36       19  Female  117555
# 67       Prof          A   17       11  Female   90450
# 72       Prof          B   24       15  Female  161101
# 75       Prof          B   17       17  Female  124312
# ...

# %%
df.iloc[0]
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           49
# sex             Male
# salary        186960
# Name: 0, dtype: object

# %%
df.iloc[,0]
# Out:
#   File "<ipython-input-91-bce8c003ee5b>", line 1
#     df.iloc[,0]
#             ^
# SyntaxError: invalid syntax

# %%
df.iloc[:,0]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.iloc[0:3, 0:2]
# Out:
#    rank discipline
# 0  Prof          B
# 1  Prof          A
# 2  Prof          A

# %%
df.iloc[:,1:7]
# Out:
#    discipline  phd  service     sex  salary
# 0           B   56       49    Male  186960
# 1           A   12        6    Male   93000
# 2           A   23       20    Male  110515
# 3           A   40       31    Male  131205
# 4           B   20       18    Male  104800
# ..        ...  ...      ...     ...     ...
# 73          B   18       10  Female  105450
# 74          B   19        6  Female  104542
# 75          B   17       17  Female  124312
# 76          A   28       14  Female  109954
# 77          A   23       15  Female  109646
#
# [78 rows x 5 columns]

# %%
df.iloc[:,1:6]
# Out:
#    discipline  phd  service     sex  salary
# 0           B   56       49    Male  186960
# 1           A   12        6    Male   93000
# 2           A   23       20    Male  110515
# 3           A   40       31    Male  131205
# 4           B   20       18    Male  104800
# ..        ...  ...      ...     ...     ...
# 73          B   18       10  Female  105450
# 74          B   19        6  Female  104542
# 75          B   17       17  Female  124312
# 76          A   28       14  Female  109954
# 77          A   23       15  Female  109646
#
# [78 rows x 5 columns]

# %%
df.iloc[:,1:5]
# Out:
#    discipline  phd  service     sex
# 0           B   56       49    Male
# 1           A   12        6    Male
# 2           A   23       20    Male
# 3           A   40       31    Male
# 4           B   20       18    Male
# ..        ...  ...      ...     ...
# 73          B   18       10  Female
# 74          B   19        6  Female
# 75          B   17       17  Female
# 76          A   28       14  Female
# 77          A   23       15  Female
#
# [78 rows x 4 columns]

# %%
df.iloc[4:45,0:5]
# Out:
#          rank discipline  phd  service     sex
# 4        Prof          B   20       18    Male
# 5        Prof          A   20       20    Male
# 6   AssocProf          A   20       17    Male
# 7        Prof          A   18       18    Male
# 8        Prof          A   29       19    Male
# 9        Prof          A   51       51    Male
# 10       Prof          B   39       33    Male
# 11       Prof          B   23       23    Male
# 12   AsstProf          B    1        0    Male
# 13       Prof          B   35       33    Male
# 14       Prof          B   25       19    Male
# 15       Prof          B   17        3    Male
# 16   AsstProf          B    8        3    Male
# 17   AsstProf          B    4        0    Male
# 18       Prof          A   19        7    Male
# 19       Prof          A   29       27    Male
# 20   AsstProf          B    4        4    Male
# 21       Prof          A   33       30    Male
# 22   AsstProf          A    4        2    Male
# ...

# %%
df['phd'].agg('min')
# Out:
# 1

# %%
df['phd'].agg(['min', 'max', 'mean'])
# Out:
# min      1.000000
# max     56.000000
# mean    19.705128
# Name: phd, dtype: float64

# %%
df[['salary','phd']].agg(['min', 'max', 'mean'])
# Out:
#              salary        phd
# min    57800.000000   1.000000
# max   186960.000000  56.000000
# mean  108023.782051  19.705128

# %%
cal=pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
cal
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 0       -122.05     37.37  ...         6.6085            344700.0
# 1       -118.30     34.26  ...         3.5990            176500.0
# 2       -117.81     33.78  ...         5.7934            270500.0
# 3       -118.36     33.82  ...         6.1359            330000.0
# 4       -119.67     36.33  ...         2.9375             81700.0
# ...         ...       ...  ...            ...                 ...
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
# 2997    -119.70     36.30  ...         2.2895             62000.0
# 2998    -117.12     34.10  ...         3.2708            162500.0
# 2999    -119.63     34.42  ...         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
cal.head(10)
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -122.05     37.37  ...         6.6085            344700.0
# 1    -118.30     34.26  ...         3.5990            176500.0
# 2    -117.81     33.78  ...         5.7934            270500.0
# 3    -118.36     33.82  ...         6.1359            330000.0
# 4    -119.67     36.33  ...         2.9375             81700.0
# 5    -119.56     36.51  ...         1.6635             67000.0
# 6    -121.43     38.63  ...         1.6641             67000.0
# 7    -120.65     35.48  ...         3.2250            166900.0
# 8    -122.84     38.40  ...         3.6696            194400.0
# 9    -118.02     34.08  ...         2.3333            164200.0
#
# [10 rows x 9 columns]

# %%
cal.tail(10)
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 2990    -118.23     34.09  ...         2.6923            150000.0
# 2991    -117.17     34.28  ...         7.1997            253800.0
# 2992    -122.33     37.39  ...         6.2263            500001.0
# 2993    -117.91     33.60  ...         5.1048            500001.0
# 2994    -117.93     33.86  ...         5.5867            182500.0
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
# 2997    -119.70     36.30  ...         2.2895             62000.0
# 2998    -117.12     34.10  ...         3.2708            162500.0
# 2999    -119.63     34.42  ...         8.5608            500001.0
#
# [10 rows x 9 columns]

# %%
cal.head(50)
# Out:
#     longitude  latitude  ...  median_income  median_house_value
# 0     -122.05     37.37  ...         6.6085            344700.0
# 1     -118.30     34.26  ...         3.5990            176500.0
# 2     -117.81     33.78  ...         5.7934            270500.0
# 3     -118.36     33.82  ...         6.1359            330000.0
# 4     -119.67     36.33  ...         2.9375             81700.0
# 5     -119.56     36.51  ...         1.6635             67000.0
# 6     -121.43     38.63  ...         1.6641             67000.0
# 7     -120.65     35.48  ...         3.2250            166900.0
# 8     -122.84     38.40  ...         3.6696            194400.0
# 9     -118.02     34.08  ...         2.3333            164200.0
# 10    -118.24     33.98  ...         2.2054            125000.0
# 11    -119.12     35.85  ...         2.4167             58300.0
# 12    -121.93     37.25  ...         4.6900            252600.0
# 13    -117.03     32.97  ...         4.5625            231200.0
# ...

# %%
cal.describe()
# Out:
#          longitude    latitude  ...  median_income  median_house_value
# count  3000.000000  3000.00000  ...    3000.000000          3000.00000
# mean   -119.589200    35.63539  ...       3.807272        205846.27500
# std       1.994936     2.12967  ...       1.854512        113119.68747
# min    -124.180000    32.56000  ...       0.499900         22500.00000
# 25%    -121.810000    33.93000  ...       2.544000        121200.00000
# 50%    -118.485000    34.27000  ...       3.487150        177650.00000
# 75%    -118.020000    37.69000  ...       4.656475        263975.00000
# max    -114.490000    41.92000  ...      15.000100        500001.00000
#
# [8 rows x 9 columns]

# %%
cal.shape
# Out:
# (3000, 9)

# %%
cal.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
cal.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
cal.values
# Out:
# array([[-1.22050e+02,  3.73700e+01,  2.70000e+01, ...,  6.06000e+02,
#          6.60850e+00,  3.44700e+05],
#        [-1.18300e+02,  3.42600e+01,  4.30000e+01, ...,  2.77000e+02,
#          3.59900e+00,  1.76500e+05],
#        [-1.17810e+02,  3.37800e+01,  2.70000e+01, ...,  4.95000e+02,
#          5.79340e+00,  2.70500e+05],
#        ...,
#        [-1.19700e+02,  3.63000e+01,  1.00000e+01, ...,  2.20000e+02,
#          2.28950e+00,  6.20000e+04],
#        [-1.17120e+02,  3.41000e+01,  4.00000e+01, ...,  1.40000e+01,
#          3.27080e+00,  1.62500e+05],
#        [-1.19630e+02,  3.44200e+01,  4.20000e+01, ...,  2.60000e+02,
#          8.56080e+00,  5.00001e+05]])

# %%
cal.mean()
# Out:
# longitude               -119.589200
# latitude                  35.635390
# housing_median_age        28.845333
# total_rooms             2599.578667
# total_bedrooms           529.950667
# population              1402.798667
# households               489.912000
# median_income              3.807272
# median_house_value    205846.275000
# dtype: float64

# %%
cal.min()
# Out:
# longitude              -124.1800
# latitude                 32.5600
# housing_median_age        1.0000
# total_rooms               6.0000
# total_bedrooms            2.0000
# population                5.0000
# households                2.0000
# median_income             0.4999
# median_house_value    22500.0000
# dtype: float64

# %%
cal.describe()
# Out:
#          longitude    latitude  ...  median_income  median_house_value
# count  3000.000000  3000.00000  ...    3000.000000          3000.00000
# mean   -119.589200    35.63539  ...       3.807272        205846.27500
# std       1.994936     2.12967  ...       1.854512        113119.68747
# min    -124.180000    32.56000  ...       0.499900         22500.00000
# 25%    -121.810000    33.93000  ...       2.544000        121200.00000
# 50%    -118.485000    34.27000  ...       3.487150        177650.00000
# 75%    -118.020000    37.69000  ...       4.656475        263975.00000
# max    -114.490000    41.92000  ...      15.000100        500001.00000
#
# [8 rows x 9 columns]

# %%
cal['total_rooms']
# Out:
# 0       3885.0
# 1       1510.0
# 2       3589.0
# 3         67.0
# 4       1241.0
#          ...
# 2995    1450.0
# 2996    5257.0
# 2997     956.0
# 2998      96.0
# 2999    1765.0
# Name: total_rooms, Length: 3000, dtype: float64

# %%
cal[['total_bedrooms']]
# Out:
#       total_bedrooms
# 0              661.0
# 1              310.0
# 2              507.0
# 3               15.0
# 4              244.0
# ...              ...
# 2995           642.0
# 2996          1082.0
# 2997           201.0
# 2998            14.0
# 2999           263.0
#
# [3000 rows x 1 columns]

# %%
cal[['total_bedrooms', 'total_rooms']]
# Out:
#       total_bedrooms  total_rooms
# 0              661.0       3885.0
# 1              310.0       1510.0
# 2              507.0       3589.0
# 3               15.0         67.0
# 4              244.0       1241.0
# ...              ...          ...
# 2995           642.0       1450.0
# 2996          1082.0       5257.0
# 2997           201.0        956.0
# 2998            14.0         96.0
# 2999           263.0       1765.0
#
# [3000 rows x 2 columns]

# %%
cal
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 0       -122.05     37.37  ...         6.6085            344700.0
# 1       -118.30     34.26  ...         3.5990            176500.0
# 2       -117.81     33.78  ...         5.7934            270500.0
# 3       -118.36     33.82  ...         6.1359            330000.0
# 4       -119.67     36.33  ...         2.9375             81700.0
# ...         ...       ...  ...            ...                 ...
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
# 2997    -119.70     36.30  ...         2.2895             62000.0
# 2998    -117.12     34.10  ...         3.2708            162500.0
# 2999    -119.63     34.42  ...         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
cal.groupby(['median_house_value']).mean()
# Out:
#                     longitude  latitude  ...  households  median_income
# median_house_value                       ...
# 22500.0            -117.16000   32.7100  ...     375.000       1.091800
# 37500.0            -123.08000   40.4000  ...      49.000       1.796900
# 39200.0            -119.97000   36.4400  ...     220.000       2.177100
# 39800.0            -117.65000   35.0000  ...     241.000       1.910700
# 40000.0            -122.06000   37.3900  ...     274.000       3.687500
# ...                       ...       ...  ...         ...            ...
# 494700.0           -118.43000   34.0400  ...     412.000       5.858700
# 495500.0           -118.39000   33.8800  ...     416.000       5.968300
# 495800.0           -122.71000   37.8800  ...     250.000       4.312500
# 500000.0           -121.29500   36.5025  ...     483.000       5.231100
# 500001.0           -119.65416   35.1520  ...     520.408       7.703998
#
# [1784 rows x 8 columns]

# %%
cal.groupby(['latitude']).mean()
# Out:
#            longitude  housing_median_age  ...  median_income  median_house_value
# latitude                                  ...
# 32.56    -117.090000            8.000000  ...       4.898400       151500.000000
# 32.57    -117.103333           28.333333  ...       2.752867       125666.666667
# 32.58    -117.090000           22.500000  ...       3.594150       137183.333333
# 32.59    -117.090000           20.500000  ...       3.367000       146650.000000
# 32.60    -117.070000           13.000000  ...       2.290300       106300.000000
# ...              ...                 ...  ...            ...                 ...
# 41.31    -122.320000           45.000000  ...       1.191500        71900.000000
# 41.54    -123.920000           22.000000  ...       2.020200        71100.000000
# 41.63    -122.640000           19.000000  ...       3.106200       100000.000000
# 41.80    -124.170000           16.000000  ...       3.755700       109400.000000
# ...

# %%
cal.groupby(['latitude', 'longitude']).min()
# Out:
#                     housing_median_age  ...  median_house_value
# latitude longitude                      ...
# 32.56    -117.09                   8.0  ...            151500.0
# 32.57    -117.12                  35.0  ...            133300.0
#          -117.11                  32.0  ...            140500.0
#          -117.08                  18.0  ...            103200.0
# 32.58    -117.13                  27.0  ...            156000.0
# ...                                ...  ...                 ...
# 41.31    -122.32                  45.0  ...             71900.0
# 41.54    -123.92                  22.0  ...             71100.0
# 41.63    -122.64                  19.0  ...            100000.0
# 41.80    -124.17                  16.0  ...            109400.0
# 41.92    -124.16                  19.0  ...             75000.0
#
# [2712 rows x 7 columns]

# %%
cal[cal.total_bedrooms>2000]
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 33      -118.08     34.55  ...         4.5237            141800.0
# 292     -116.36     33.78  ...         3.3799            239300.0
# 321     -121.73     37.68  ...         5.4496            238900.0
# 405     -120.67     35.62  ...         3.8661            168100.0
# 650     -117.73     33.57  ...         4.8488            194400.0
# 753     -118.37     33.95  ...         3.1110            247600.0
# 900     -117.22     32.95  ...         6.3570            322500.0
# 947     -117.23     33.91  ...         4.0473            127200.0
# 976     -117.58     34.11  ...         4.7547            157600.0
# 978     -121.53     38.48  ...         4.8811            212200.0
# 1146    -117.27     33.15  ...         4.6357            244900.0
# 1283    -117.18     32.92  ...         5.1960            210700.0
# 1352    -121.87     37.42  ...         6.4419            264500.0
# ...

# %%
cal[cal.total_rooms>20000]
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 292     -116.36     33.78  ...         3.3799            239300.0
# 321     -121.73     37.68  ...         5.4496            238900.0
# 978     -121.53     38.48  ...         4.8811            212200.0
# 1146    -117.27     33.15  ...         4.6357            244900.0
# 1597    -117.12     33.49  ...         3.9963            191100.0
# 2429    -117.20     33.58  ...         4.5936            174300.0
#
# [6 rows x 9 columns]

# %%
cal[(cal.total_rooms>20000) & (cal.total_bedrooms>5000) ]
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 978     -121.53     38.48  ...         4.8811            212200.0
# 2429    -117.20     33.58  ...         4.5936            174300.0
#
# [2 rows x 9 columns]
